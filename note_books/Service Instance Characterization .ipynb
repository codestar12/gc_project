# %%
import pandas as pd
import numpy as np

# %%
service_instances = pd.read_csv("/Users/codyblakeney/gc_project/data/container_usage.csv", header=None, 
                                names=["ts", "instance_id", "cpu_util", "mem_util", "disk_util", "load1", "load5","load15", "avg_cpi", "avg_mpki", "max_cpi", "max_mpki"])

# %%
service_instances.head()
# Out:
#       ts  instance_id  cpu_util  mem_util  disk_util  load1  load5  load15  \
# 0  42900          106     42.84     65.52      17.14   3.14   3.40    3.66
# 1  42600          107      3.30     24.00       5.20   0.54   0.38    0.30
# 2  42300          108      3.14     25.60      10.60   0.08   0.14    0.20
# 3  42000          109      3.82     42.00      13.90   0.10   0.16    0.20
# 4  41700          110      5.82     24.90       7.40   0.74   0.62    0.60
#
#     avg_cpi  avg_mpki   max_cpi   max_mpki
# 0  0.064628  0.034337  0.726102   0.457576
# 1  0.155430  0.550153  2.211467  12.187318
# 2  0.199342  0.294852  2.633724   3.997216
# 3  0.238470  0.292426  2.203077   2.942878
# 4  0.136100  0.161496  1.622428   2.469633

# %%
service_instances.size
# Out:
# 17770872

# %% [markdown]
# ### Way to many samples to plot easily. Need to sub sample

# %%
service_instances = service_instances.sample(frac=.01, replace=False)

# %%
from bokeh.plotting import figure, show
from bokeh.charts import Histogram
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="066c4a4d-b81a-4bc2-ab28-e8fcd50ec3ff">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## CPI might be a helpful measure of performance we need to maintain as if we make a model to prodict performance

# %%
p = Histogram(service_instances["avg_cpi"])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c666c057-540a-42b2-a932-4669dad21e59"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c666c057-540a-42b2-a932-4669dad21e59");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c666c057-540a-42b2-a932-4669dad21e59");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c666c057-540a-42b2-a932-4669dad21e59' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"027ff2e5-a32e-467a-9e06-03c14625c153":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0e9d0632-9ba6-4b21-a505-1fafa91be16e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ed49c28e-87f2-4988-964c-012820008576","type":"Rect"},{"attributes":{"plot":{"id":"6b3be1e7-bed4-4148-b35d-802a1cec3068","subtype":"Chart","type":"Plot"}},"id":"a08a1e68-998c-4272-a420-803600d99451","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(0.028041, 0.032046]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(0.028041, 0.032046]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.004005799010407506],"x":["0.0300435"],"y":[1.0]}},"id":"876428dd-5a8e-4578-8ea2-6f9f2a243e08","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(0.024035, 0.028041]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.024035, 0.028041]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.004005799010407506],"x":["0.026038"],"y":[0.0]}},"id":"c611cc34-4ea0-4398-b699-46cc7e24170f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"c611cc34-4ea0-4398-b699-46cc7e24170f","type":"ColumnDataSource"},"glyph":{"id":"3f2d6d91-75b5-4ffb-adfe-4babe1aeb880","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f9506244-f6d5-4b8c-9bb8-36d660161846","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d2c0686f-1c4f-4134-9be4-b30d5c1a04ae","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(0.032046, 0.036052]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(0.032046, 0.036052]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.004005799010407506],"x":["0.034048999999999996"],"y":[2.0]}},"id":"6f58c227-c8eb-4af3-a16f-79f07fa44e6f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(0.588852, 0.592858]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.588852, 0.592858]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.00400579901040754],"x":["0.590855"],"y":[0.0]}},"id":"32268cf6-21df-48fb-b2b8-802bfed0f7f5","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"32268cf6-21df-48fb-b2b8-802bfed0f7f5","type":"ColumnDataSource"},"glyph":{"id":"b337e4a8-1071-4437-b095-96c82f4cfdc1","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"
","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field" ...

# %% [markdown]
# ### This looks like instances are aggresively over provisioning memory. We'll see if that is helpful later

# %% [markdown]
# ### Wanted to see if there were any peaks in service instances, but it looks like its pretty evenly distributed

# %%
p = Histogram(service_instances["ts"])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9e4effe5-ab91-40ae-b04f-c651961e2dfb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9e4effe5-ab91-40ae-b04f-c651961e2dfb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9e4effe5-ab91-40ae-b04f-c651961e2dfb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9e4effe5-ab91-40ae-b04f-c651961e2dfb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ae15a84d-e719-4547-a22b-082db647e2a9":{"roots":{"references":[{"attributes":{"plot":{"id":"07f48288-5f2e-45f7-a6fc-be390fd030a0","subtype":"Chart","type":"Plot"}},"id":"88235e94-96a9-406c-99a8-12f998317047","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(61908.000000, 63624.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[626.0],"label":["(61908.000000, 63624.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[1716.0],"x":["62766.0"],"y":[313.0]}},"id":"a36e58cb-014d-492b-9d77-fa804f56c612","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"07546b72-113c-41c9-afcb-b798455324a1","type":"BoxAnnotation"},"plot":{"id":"07f48288-5f2e-45f7-a6fc-be390fd030a0","subtype":"Chart","type":"Plot"}},"id":"83936f27-0c32-4841-a163-87ca8f9aedd8","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"4afe7ec3-626f-4a52-b3e4-c6d6e2d7b851","type":"ColumnDataSource"},"glyph":{"id":"043cce30-f2bc-4b83-9704-49d7637a1f34","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"67b557d7-7680-4563-9f65-01ebf4f6fec3","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"07f48288-5f2e-45f7-a6fc-be390fd030a0","subtype":"Chart","type":"Plot"}},"id":"dc58db3d-0c05-40cf-9d7e-c093fb1a423d","type":"SaveTool"},{"attributes":{"plot":{"id":"07f48288-5f2e-45f7-a6fc-be390fd030a0","subtype":"Chart","type":"Plot"}},"id":"e5b049e4-411a-4ced-96c5-c45e2813256a","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(56760.000000, 58476.000000]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[521.0],"label":["(56760.000000, 58476.000000]"],"line_alpha":[1.0],"line_color":["black"],"width":[1716.0],"x":["57618.0"],"y":[260.5]}},"id":"664d9b92-d2db-41af-aa81-9cfec1a1c00b","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"07546b72-113c-41c9-afcb-b798455324a1","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"95a7bb3a-c27e-41af-97e6-7c75f94756de","type":"Rect"},{"attributes":{"plot":{"id":"07f48288-5f2e-45f7-a6fc-be390fd030a0","subtype":"Chart","type":"Plot"}},"id":"dcbd71d1-bc80-4105-9b29-2834ff0c19f2","type":"ResetTool"},{"attributes":{"plot":{"id":"07f48288-5f2e-45f7-a6fc-be390fd030a0","subtype":"Chart","type":"Plot"}},"id":"663d118f-92fa-4f53-a66f-e82d1906d992","type":"HelpTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c049cea2-edd6-4789-b5d0-b8c29db6f80f","type":"Rect"},{"attributes":{"data_source":{"id":"664d9b92-d2db-41af-aa81-9cfec1a1c00b","type":"ColumnDataSource"},"glyph":{"id":"95a7bb3a-c27e-41af-97e6-7c75f94756de","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"971f90f1-ea4a-4dd2-8751-adf8b18c81e5","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"986f6ac1-08d0-4196-b5a8-1b9588b3d7a4","type":"ColumnDataSource"},"glyph":{"id":"a386fa64-9a95-4160-9ecd-a796653309de","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a7f43f53-0448-4b7b-a989-e366ee3c1e0a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"da97322d-d419-42c7-a919-f0f468f436fb","type":"ColumnDataSource"},"glyph":{"id":"81a047be-411c-45c4-a53c-3e4657 ...
