# %%
import pandas as pd
import numpy as np

# %%
service_containers = pd.read_csv("/Users/codyblakeney/gc_project/data/container_event.csv")

# %%
service_containers.head()
# Out:
#    ts   event  instance_id  machine_id  plan_cpu  plan_mem  plan_disk  \
# 0   0  Create        10000         934         4  0.042409   0.034085
# 1   0  Create         1000        1295         8  0.084819   0.056809
# 2   0  Create        10001         668         8  0.084819   0.056809
# 3   0  Create        10002        1217         8  0.084819   0.056809
# 4   0  Create        10003        1019         4  0.042409   0.034085
#
#                     cpuset  Unnamed: 8
# 0              40|41|42|43         NaN
# 1  56|57|58|59|60|61|62|63         NaN
# 2  24|25|26|27|28|29|30|31         NaN
# 3        4|5|6|7|8|9|10|11         NaN
# 4              36|37|38|39         NaN

# %%
#service_containers = service_containers.sample(frac=, replace=False)

# %%
from bokeh.plotting import figure, show
from bokeh.charts import Histogram
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5b166315-cd5a-4730-b51b-f866f54da7a7">Loading BokehJS ...</span>
#     </div>

# %%
p = Histogram(service_containers["plan_mem"])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a17e4a8a-4105-4e29-bf45-c408ff7db830"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a17e4a8a-4105-4e29-bf45-c408ff7db830");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a17e4a8a-4105-4e29-bf45-c408ff7db830");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a17e4a8a-4105-4e29-bf45-c408ff7db830' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9a7c0138-8a45-4850-b7bf-a814c18769db":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(0.689046, 0.692839]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.689046, 0.692839]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0037922421644688287],"x":["0.6909425"],"y":[0.0]}},"id":"1a332a27-c9e1-4778-9961-3e7597197842","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9dda27dc-089c-411e-baab-b43d4348bc35","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(0.692839, 0.696631]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.692839, 0.696631]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0037922421644688287],"x":["0.694735"],"y":[0.0]}},"id":"3e57da28-f6d9-48db-a4e0-0c3bb2956524","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"1a332a27-c9e1-4778-9961-3e7597197842","type":"ColumnDataSource"},"glyph":{"id":"0d88f845-9082-42fa-afa2-364000a668b1","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"7c7c7996-fee4-41dc-bdd8-88934bf98b81","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7dc20429-5d4d-41b8-baab-5a9299f98023","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(0.696631, 0.700423]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.696631, 0.700423]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0037922421644688287],"x":["0.698527"],"y":[0.0]}},"id":"32e33bbf-3417-4007-b774-95d1826e1cea","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"45c5dfc5-ff94-4fcc-bb06-36f2693e9d3a","type":"Rect"},{"attributes":{"data_source":{"id":"ec0470a8-811c-44e9-b5e8-cd16a8fd5ba0","type":"ColumnDataSource"},"glyph":{"id":"f80f304c-c2a6-45c7-bdbe-c1dc6f8238e8","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"591de403-3680-420a-8778-551d692f1779","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3e57da28-f6d9-48db-a4e0-0c3bb2956524","type":"ColumnDataSource"},"glyph":{"id":"9dda27dc-089c-411e-baab-b43d4348bc35","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"8eb63cbd-3b85-43a4-b0bb-4ab6397746e3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1644e821-d7b9-415a-a5e6-4afc63943d06","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(0.700423, 0.704215]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(0.700423, 0.704215]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.0037922421644688287],"x":["0.702319"],"y":[0.0]}},"id":"26bd457a-c918-46a2-ac6b-711de82aad8f","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_ ...

# %%
p = Histogram(service_containers["plan_cpu"])
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7889609a-7f2e-4b30-ad2e-dcfc087a671f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7889609a-7f2e-4b30-ad2e-dcfc087a671f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7889609a-7f2e-4b30-ad2e-dcfc087a671f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7889609a-7f2e-4b30-ad2e-dcfc087a671f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"68637090-fcd2-4d5e-a749-c77091f50827":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a9bc24bd-3ad2-45f7-bf9f-ba95b4c1ac5f","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(8.500000, 8.857143]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(8.500000, 8.857143]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.35714285714285765],"x":["8.6785715"],"y":[0.0]}},"id":"4dec54b9-3534-4f47-8763-743c7b186829","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e8f406d2-a601-4436-8702-20866877df4e","type":"Rect"},{"attributes":{"data_source":{"id":"13ffe022-1a52-4138-8158-387016ff6cec","type":"ColumnDataSource"},"glyph":{"id":"2375e55d-d14f-4a6c-9478-51c2c1bb77fd","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"f2f31bdc-f4f6-4aba-b350-ea512c07c28f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(12.785714, 13.142857]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(12.785714, 13.142857]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.3571428571428559],"x":["12.964285499999999"],"y":[0.0]}},"id":"8ee959e0-24fb-4ee4-bea8-2552fb195c53","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5b93af20-27ea-4c35-be1d-8d064201afc0","type":"ColumnDataSource"},"glyph":{"id":"640f54df-6b71-47f8-aaa3-f8839399d045","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"a4fdf6fe-8e94-4100-ba07-9382fc1b4f45","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9193c3e2-0dd5-425c-9b27-11f425c2d614","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"15d6422b-4d44-4ff2-927e-65fd801fe56d","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(12.428571, 12.785714]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(12.428571, 12.785714]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.35714285714285765],"x":["12.6071425"],"y":[0.0]}},"id":"ff98b694-cfec-4561-8f45-c6f3f01fe4cf","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"a0d6ae1a-1e25-4c21-a79e-c4a0cbafcf6e","type":"ColumnDataSource"},"glyph":{"id":"a87daabb-83e4-43ca-98a5-6b6b4e26b93c","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"008a7f41-8db9-43b5-bcdc-96520e3027c9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(5.285714, 5.642857]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(5.285714, 5.642857]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.35714285714285765],"x":["5.4642855"],"y":[0.0]}},"id":"f7a883e6-517c-4de6-a6bd-e3fe7ef231cb","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"ff98b694-cfec-4561-8f45-c6f3f01fe4cf","type":"ColumnDataSource"},"glyph":{"id":"e8f406d2-a601-4 ...

# %%
from fractions import Fraction

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/codyblakeney/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2392             try:
# -> 2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'E'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-8a796cc8395d> in <module>()
# ----> 1 sum(service_containers["E"])
#
# /Users/codyblakeney/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Users/codyblakeney/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Users/codyblakeney/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /Users/codyblakeney/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/codyblakeney/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'E'
